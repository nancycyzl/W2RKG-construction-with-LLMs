# %% [markdown]
# **Reference**:
# https://colab.research.google.com/drive/1Ys44kVvmeZtnICzWz0xgpRnrIOjZAuxp?usp=sharing#scrollTo=pCqnaKmlO1U9
#
#
# **This script contains**
#
# 1. finetuning of llama3.1 model: save to gdrive by default
# 2. inference: abtain w2r_result.json file, save to gdrive by default
#
# **Note**
#
# Only extract waste and transformed_resource
# and add transforming_process as an empty list
#
# **Before start**
#
# - runtime change to GPU T4

# %% [markdown]
# ## Prepare packages and models

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install unsloth
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# Out:
# Collecting unsloth
#   Downloading unsloth-2024.11.5-py3-none-any.whl.metadata (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 1.7 MB/s eta 0:00:00
# Collecting unsloth-zoo>=2024.11.1 (from unsloth)
#   Downloading unsloth_zoo-2024.11.4-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from unsloth) (2.5.0+cu121)
# Collecting xformers>=0.0.27.post2 (from unsloth)
#   Downloading xformers-0.0.28.post3-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (1.0 kB)
# Collecting bitsandbytes (from unsloth)
#   Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl.metadata (3.5 kB)
# Collecting triton>=3.0.0 (from unsloth)
#   Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from unsloth) (24.1)
# Collecting tyro (from unsloth)
#   Downloading tyro-0.8.14-py3-none-any.whl.metadata (8.4 kB)
# Collecting transformers>=4.46.1 (from unsloth)
#   Downloading transformers-4.46.2-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 3.0 MB/s eta 0:00:00
# Collecting datasets>=2.16.0 (from unsloth)
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from unsloth) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from unsloth) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.44.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from unsloth) (1.26.4)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.34.2)
# Collecting trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9 (from unsloth)
#   Downloading trl-0.12.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.13.2)
# Requirement already satisfied: protobuf<4.0.0 in /usr/local/lib/python3.10/dist-packages (from unsloth) (3.20.3)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from unsloth) (0.24.7)
# Collecting hf-transfer (from unsloth)
#   Downloading hf_transfer-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.1->unsloth) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.34.1->unsloth) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (17.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets>=2.16.0->unsloth)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (2.32.3)
# Collecting xxhash (from datasets>=2.16.0->unsloth)
#   Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets>=2.16.0->unsloth)
#   Downloading multiprocess-0.70.16-py310-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=2.16.0->unsloth)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth) (3.10.10)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unsloth) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.4.0->unsloth) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.4.0->unsloth) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.4.0->unsloth) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.4.0->unsloth) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth) (2024.9.11)
# Collecting tokenizers<0.21,>=0.20 (from transformers>=4.46.1->unsloth)
#   Downloading tokenizers-0.20.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (13.9.3)
# Collecting torch>=2.4.0 (from unsloth)
#   Downloading torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.4.0->unsloth)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth) (0.16)
# Collecting shtab>=1.5.6 (from tyro->unsloth)
#   Downloading shtab-1.7.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (2.18.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.4.0->unsloth) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2024.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.16.0->unsloth) (0.2.0)
# Downloading unsloth-2024.11.5-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.8/161.8 kB 9.5 MB/s eta 0:00:00
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 27.2 MB/s eta 0:00:00
# Downloading transformers-4.46.2-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 71.5 MB/s eta 0:00:00
# Downloading triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 6.0 MB/s eta 0:00:00
# Downloading trl-0.12.0-py3-none-any.whl (310 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.2/310.2 kB 15.4 MB/s eta 0:00:00
# Downloading unsloth_zoo-2024.11.4-py3-none-any.whl (30 kB)
# Downloading xformers-0.0.28.post3-cp310-cp310-manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 64.7 MB/s eta 0:00:00
# Downloading torch-2.5.1-cp310-cp310-manylinux1_x86_64.whl (906.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.4/906.4 MB 859.5 kB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 59.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 52.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 37.4 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 57.0 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.6 MB/s eta 0:00:00
# Downloading bitsandbytes-0.44.1-py3-none-manylinux_2_24_x86_64.whl (122.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 7.9 MB/s eta 0:00:00
# Downloading hf_transfer-0.1.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 101.3 MB/s eta 0:00:00
# Downloading tyro-0.8.14-py3-none-any.whl (109 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.8/109.8 kB 8.5 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.2 MB/s eta 0:00:00
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 17.8 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 13.7 MB/s eta 0:00:00
# Downloading shtab-1.7.1-py3-none-any.whl (14 kB)
# Downloading tokenizers-0.20.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 65.7 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.5 MB/s eta 0:00:00
# Installing collected packages: xxhash, triton, shtab, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, hf-transfer, fsspec, dill, nvidia-cusparse-cu12, nvidia-cudnn-cu12, multiprocess, tyro, tokenizers, nvidia-cusolver-cu12, transformers, torch, xformers, datasets, bitsandbytes, trl, unsloth-zoo, unsloth
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.6.77
#     Uninstalling nvidia-nvjitlink-cu12-12.6.77:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.6.77
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.3.3
#     Uninstalling nvidia-cublas-cu12-12.6.3.3:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.3.3
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.5.1.17
#     Uninstalling nvidia-cudnn-cu12-9.5.1.17:
#       Successfully uninstalled nvidia-cudnn-cu12-9.5.1.17
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.44.2
#     Uninstalling transformers-4.44.2:
#       Successfully uninstalled transformers-4.44.2
#   Attempting uninstall: torch
#     Found existing installation: torch 2.5.0+cu121
#     Uninstalling torch-2.5.0+cu121:
#       Successfully uninstalled torch-2.5.0+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# torchaudio 2.5.0+cu121 requires torch==2.5.0, but you have torch 2.5.1 which is incompatible.
# torchvision 0.20.0+cu121 requires torch==2.5.0, but you have torch 2.5.1 which is incompatible.
# Successfully installed bitsandbytes-0.44.1 datasets-3.1.0 dill-0.3.8 fsspec-2024.9.0 hf-transfer-0.1.8 multiprocess-0.70.16 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 shtab-1.7.1 tokenizers-0.20.3 torch-2.5.1 transformers-4.46.2 triton-3.1.0 trl-0.12.0 tyro-0.8.14 unsloth-2024.11.5 unsloth-zoo-2024.11.4 xformers-0.0.28.post3 xxhash-3.5.0
# Found existing installation: unsloth 2024.11.5
# Uninstalling unsloth-2024.11.5:
#   Successfully uninstalled unsloth-2024.11.5
# Collecting unsloth@ git+https://github.com/unslothai/unsloth.git (from unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git)
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-vhkqd1lu/unsloth_d5b6432b33fa497483ecda4f328e79fc
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-vhkqd1lu/unsloth_d5b6432b33fa497483ecda4f328e79fc
#   Resolved https://github.com/unslothai/unsloth.git to commit 0c8c5ed81e423658ab9ae81eac5aab8d18f5d7af
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: unsloth-zoo>=2024.11.1 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.11.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (24.1)
# Requirement already satisfied: tyro in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.8.14)
# Requirement already satisfied: transformers>=4.46.1 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.46.2)
# Requirement already satisfied: datasets>=2.16.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.1.0)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.66.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.44.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.26.4)
# Requirement already satisfied: protobuf<4.0.0 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.20.3)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.24.7)
# Requirement already satisfied: hf-transfer in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.1.8)
# Requirement already satisfied: bitsandbytes>=0.43.3 in /usr/local/lib/python3.10/dist-packages (from unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.44.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.5.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.16.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.32.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.70.16)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.9.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.10.10)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.12.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.46.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.20.3)
# Requirement already satisfied: triton in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.1.0)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.34.2)
# Requirement already satisfied: trl!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9 in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.12.0)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from unsloth-zoo>=2024.11.1->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.13.2)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.16)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (13.9.3)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.7.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (2024.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.16.0->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes>=0.43.3->unsloth@ git+https://github.com/unslothai/unsloth.git->unsloth[colab-new]@ git+https://github.com/unslothai/unsloth.git) (3.0.2)
# Building wheels for collected packages: unsloth
#   Building wheel for unsloth (pyproject.toml) ... done
#   Created wheel for unsloth: filename=unsloth-2024.11.5-py3-none-any.whl size=161007 sha256=a50d5f3e6a9d4f4021c63f2fe8074e3ec83ae1b5e701e4b03dd2994f5a99e680
#   Stored in directory: /tmp/pip-ephem-wheel-cache-u_ye7prq/wheels/ed/d4/e9/76fb290ee3df0a5fc21ce5c2c788e29e9607a2353d8342fd0d
# Successfully built unsloth
# Installing collected packages: unsloth
# Successfully installed unsloth-2024.11.5

# %%
# !pip install bitsandbytes
# !pip install xformers
# Out:
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.10/dist-packages (0.44.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (2.5.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes) (3.0.2)
# Requirement already satisfied: xformers in /usr/local/lib/python3.10/dist-packages (0.0.28.post3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from xformers) (1.26.4)
# Requirement already satisfied: torch==2.5.1 in /usr/local/lib/python3.10/dist-packages (from xformers) (2.5.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch==2.5.1->xformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch==2.5.1->xformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.5.1->xformers) (3.0.2)

# %%
# !pip install -U "huggingface_hub[cli]"
# Out:
# Requirement already satisfied: huggingface_hub[cli] in /usr/local/lib/python3.10/dist-packages (0.24.7)
# Collecting huggingface_hub[cli]
#   Downloading huggingface_hub-0.26.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub[cli]) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub[cli]) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub[cli]) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub[cli]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub[cli]) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub[cli]) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub[cli]) (4.12.2)
# Collecting InquirerPy==0.3.4 (from huggingface_hub[cli])
#   Downloading InquirerPy-0.3.4-py3-none-any.whl.metadata (8.1 kB)
# Collecting pfzy<0.4.0,>=0.3.1 (from InquirerPy==0.3.4->huggingface_hub[cli])
#   Downloading pfzy-0.3.4-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from InquirerPy==0.3.4->huggingface_hub[cli]) (3.0.48)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub[cli]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub[cli]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub[cli]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub[cli]) (2024.8.30)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit<4.0.0,>=3.0.1->InquirerPy==0.3.4->huggingface_hub[cli]) (0.2.13)
# Downloading InquirerPy-0.3.4-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 5.7 MB/s eta 0:00:00
# Downloading huggingface_hub-0.26.2-py3-none-any.whl (447 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.5/447.5 kB 21.5 MB/s eta 0:00:00
# Downloading pfzy-0.3.4-py3-none-any.whl (8.5 kB)
# Installing collected packages: pfzy, InquirerPy, huggingface_hub
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.24.7
#     Uninstalling huggingface-hub-0.24.7:
#       Successfully uninstalled huggingface-hub-0.24.7
# Successfully installed InquirerPy-0.3.4 huggingface_hub-0.26.2 pfzy-0.3.4

# %%
# from huggingface_hub import notebook_login
# notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# this takes around 9mins
# model size > 16GB
# !huggingface-cli download meta-llama/Meta-Llama-3.1-8B-Instruct --repo-type model --local-dir "/content/drive/MyDrive/Colab Notebooks/W2R/Meta-Llama-3.1-8B"
# Out:
# Streaming output truncated to the last 5000 lines.
#
#
#
#
#
# consolidated.00.pth:  53% 8.59G/16.1G [06:09<02:57, 42.0MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  54% 8
 43.0MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  98% 15.8G/16.1G [08:57<00:06, 42.8MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  98% 15.8G/16.1G [08:58<00:06, 42.8MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  98% 15.8G/16.1G [08:58<00:06, 42.7MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  98% 15.8G/16.1G [08:58<00:06, 42.9MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  98% 15.8G/16.1G [08:58<00:05, 43.0MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  99% 15.8G/16.1G [08:59<00:05, 43.2MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  99% 15.8G/16.1G [08:59<00:05, 43.1MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  99% 15.8G/16.1G [08:59<00:05, 43.0MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  99% 15.9G/16.1G [08:59<00:04, 42.9MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  99% 15.9G/16.1G [09:00<00:04, 42.9MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  99% 15.9G/16.1G [09:00<00:04, 43.0MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  99% 15.9G/16.1G [09:00<00:04, 43.0MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  99% 15.9G/16.1G [09:00<00:03, 42.8MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  99% 15.9G/16.1G [09:01<00:03, 42.9MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  99% 15.9G/16.1G [09:01<00:03, 42.9MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  99% 15.9G/16.1G [09:01<00:03, 42.7MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  99% 15.9G/16.1G [09:01<00:02, 42.9MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  99% 15.9G/16.1G [09:02<00:02, 42.7MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  99% 16.0G/16.1G [09:02<00:02, 43.0MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  99% 16.0G/16.1G [09:02<00:02, 43.1MB/s]
#
#
#
#
#
#
# consolidated.00.pth:  99% 16.0G/16.1G [09:02<00:01, 42.9MB/s]
#
#
#
#
#
#
# consolidated.00.pth: 100% 16.0G/16.1G [09:03<00:01, 42.9MB/s]
#
#
#
#
#
#
# consolidated.00.pth: 100% 16.0G/16.1G [09:03<00:01, 42.9MB/s]
#
#
#
#
#
#
# consolidated.00.pth: 100% 16.0G/16.1G [09:03<00:01, 43.0MB/s]
#
#
#
#
#
#
# consolidated.00.pth: 100% 16.0G/16.1G [09:03<00:00, 43.0MB/s]
#
#
#
#
#
#
# consolidated.00.pth: 100% 16.0G/16.1G [09:04<00:00, 42.0MB/s]
#
#
#
#
#
#
# consolidated.00.pth: 100% 16.0G/16.1G [09:04<00:00, 43.0MB/s]
#
#
#
#
#
#
# consolidated.00.pth: 100% 16.1G/16.1G [09:04<00:00, 43.0MB/s]
#
#
#
#
#
#
# consolidated.00.pth: 100% 16.1G/16.1G [09:04<00:00, 29.5MB/s]
# Download complete. Moving file to /content/drive/MyDrive/Colab Notebooks/W2R/Meta-Llama-3.1-8B/original/consolidated.00.pth
# Fetching 17 files: 100% 17/17 [09:08<00:00, 32.26s/it]
# /content/drive/MyDrive/Colab Notebooks/W2R/Meta-Llama-3.1-8B

# %%
from unsloth import FastLanguageModel
import torch

max_seq_length = 2048
dtype = None
load_in_4bit = True

orig_model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "/content/drive/MyDrive/Colab Notebooks/W2R//Meta-Llama-3.1-8B-Instruct",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# ==((====))==  Unsloth 2024.11.5: Fast Llama patching. Transformers = 4.46.2.
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.5.1+cu124. CUDA = 7.5. CUDA Toolkit = 12.4.
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# /content/drive/MyDrive/Colab Notebooks/W2R//Meta-Llama-3.1-8B-Instruct does not have a padding token! Will use pad_token = <|finetune_right_pad_id|>.

# %% [markdown]
# ## Inference - test initial performance

# %%
from datasets import Dataset
import json
import os

# %%
FastLanguageModel.for_inference(orig_model) # Enable native 2x faster inference
# Out:
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(128256, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaAttention(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): LlamaExtendedRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#           (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#           (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#         (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#       )
#     )
#     (norm): LlamaRMSNorm((4096,), eps=1e-05)
#     (rotary_emb): LlamaRotaryEmbedding()
#   )
#   (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
# )

# %%
def make_instruction_from_abstract():
  instruction_template = """Please read the following text and extract the waste-to-resource information into a json structure with keys of waste and transformed_resource.
The values should be list of strings. You should only use names or phrases to describe wastes and resources.
Keep the value empty if there is no corresponding information. Do not include any explanation. Do not include nested json content.
Follow the format:
{
   "waste": [],
   "transformed_resource": []
}
"""
  return instruction_template

def formatted_prompt(abstract)-> str:
  instruction = make_instruction_from_abstract()
  input_x = abstract

  llama31_prompt="""<|begin_of_text|><|start_header_id|>system<|end_header_id|>

{}<|eot_id|><|start_header_id|>user<|end_header_id|>

{}<|eot_id|><|start_header_id|>assistant<|end_header_id|>"""

  formatted_prompt = llama31_prompt.format(instruction, input_x)
  return formatted_prompt

# %% [markdown]
# test one example

# %%
from transformers import TextIteratorStreamer

abstract = "The valorization of tannins from forest by-products is a major opportunity for the sustainable development of the forestry industry. Herein we report the laccase-mediated polymerization of tannins obtained from an aqueous pine bark extract. The reaction was conducted under an oxygen atmosphere at 50°C for 60 min and followed by UV–Vis, fluorescence intensity, phenol content, and viscosity measurements. An insoluble polymer was obtained after 45 min, which was attributed to coupling reactions triggered by phenoxyl radicals within the tannins mixture. The polymer showed a marked increase in thermal stability compared with the precursor pine bark extract, with a total mass loss of less than 12% at temperatures up to 500°C, suggesting potential practical applications in flame retardant materials. Additionally, the polymer showed an 85% DPPH activity and a 60% attenuation of singlet oxygen release upon light irradiation, which supports antioxidant and photoprotective properties for the prepared material. To the best of our knowledge, this is the first report to describe the formation of an insoluble polymer by direct enzymatic reaction of an aqueous tannin extract. In this case, soluble tannins are the sole reactants used to produce a promising versatile material for forest waste valorization. © 2024 Wiley Periodicals LLC."
inputs_string = formatted_prompt(abstract)

inputs = tokenizer([inputs_string], return_tensors="pt").to("cuda")

# Initialize the TextIteratorStreamer
text_iter_streamer = TextIteratorStreamer(tokenizer)

# Generate the content using the model and the streamer
_ = orig_model.generate(**inputs, streamer=text_iter_streamer, max_new_tokens=128)

# Collect the generated tokens from the streamer and join them into a single string
generated_text = "".join([token for token in text_iter_streamer])

# Remove the original input part from the generated text, if needed
original_input_text = tokenizer.decode(inputs['input_ids'][0], skip_special_tokens=True)
generated_text = generated_text[len(original_input_text):].strip()

# Print or use the generated content
print("Result: ")
print(generated_text)
# Out:
# Result:
# used to produce a promising versatile material for forest waste valorization. © 2024 Wiley Periodicals LLC.<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# {
#   "waste": ["pine bark extract"],
#   "transformed_resource": ["insoluble polymer", "flame retardant materials", "versatile material"]
# }<|eot_id|>

# %% [markdown]
# run on test abstracts and save result

# %%
import pandas as pd
import logging
import json
import time
import ast
import re

# %%
def extract(abstract):
  inputs_string = formatted_prompt(abstract)
  inputs = tokenizer([inputs_string], return_tensors="pt").to("cuda")

  # Initialize the TextIteratorStreamer
  text_iter_streamer = TextIteratorStreamer(tokenizer)

  # generate
  _ = orig_model.generate(**inputs, streamer=text_iter_streamer, max_new_tokens=1024)
  generated_text = "".join([token for token in text_iter_streamer])

  # Remove the original input part from the generated text, if needed
  original_input_text = tokenizer.decode(inputs['input_ids'][0], skip_special_tokens=True)
  generated_text = generated_text[len(original_input_text):].strip()

  return generated_text

def extract_postprocessing(result):
  # Extract the JSON string from the text (a single JSON object)
  json_match = re.search(r'\{.*?\}', result, re.DOTALL)
  if json_match:
    json_content = json_match.group()
    try:
      # Convert the JSON string to a JSON object
      # json_data = json.loads(json_content)    # DO NOT USE THIS: valid json format use double quotes
      json_data = ast.literal_eval(json_content)    # USE THIS: convert string to dict, single or double quotes are both ok
      # Ensure the JSON object includes the required keys
      required_keys = ["waste", "transformed_resource"]
      for key in required_keys:
          if key not in json_data:
              json_data[key] = []
      json_data["transforming_process"] = []   # add the transforming_process (placeholder)
      logging.info("Conversion succeeds")
      return json_data
    except:
      # If conversion fails, create a JSON with specified keys and empty lists
      logging.info("Conversion fails")
      json_data = {
          "waste": [],
          "transforming_process": [],
          "transformed_resource": []
      }
      return json_data
  else:
    # If no JSON string is found, return a JSON with specified keys and empty lists
    logging.info("No JSON string found")
    json_data = {
        "waste": [],
        "transforming_process": [],
        "transformed_resource": []
    }
  return json_data

def check_make_dir(directory, exist_ok=False):
  if not os.path.exists(directory):
    os.makedirs(directory)
    return directory
  else:
    if not exist_ok:
      i = 1
      # increment until finding an available name
      new_dir = f"{directory}_{i}"
      while os.path.exists(new_dir):
        i += 1
        new_dir = f"{directory}_{i}"
      os.makedirs(new_dir)
      return new_dir
    return directory

# %%
def process_abstracts(args):

  # num, model, prompt, save_dir, shot_length, shot_k

  result_json_file = os.path.join(args.save_dir, "w2r_results.json")
  result_invalid_file = os.path.join(args.save_dir, "w2r_invalid.txt")
  result_invalid_doi_file = os.path.join(args.save_dir, "w2r_invalid_doi.txt")

  df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/W2R/scopus_waste2resource.csv")
  abstract_list = df["Abstract"].tolist()
  doi_list = df["DOI"].tolist()

  if args.start_index:
    abstract_list = abstract_list[args.start_index:]
    doi_list = doi_list[args.start_index:]

  if args.num > 0:
    abstract_list = abstract_list[:args.num]
    doi_list = doi_list[:args.num]

  result_json_list = []
  result_invalid_str = ""
  result_invalid_doi_list = []

  total_time = 0

  for i, abstract in enumerate(abstract_list):
    start_time = time.time()

    # get llm output and process
    coded_abstract = abstract   # no need to wrap
    result_str = extract(coded_abstract)
    result_json = extract_postprocessing(result_str)

    # add the referece and append
    result_json["reference"] = doi_list[i]
    result_json_list.append(result_json)

    # check if the extracted information is valid
    if len(result_json["waste"]) == 0 and len(result_json["transforming_process"]) == 0 and len(result_json["transformed_resource"]) == 0:
      result_invalid_str += result_str + "\n\n----------\n\n"
      result_invalid_doi_list.append(doi_list[i])

    logging.info("----------------------------------")
    logging.info("Processing abstract {}".format(i))
    logging.info("Coded abstract: \n{}".format(coded_abstract))
    logging.info("LLM response: \n{}".format(result_str))
    logging.info("Extracted w2r: \n{}".format(result_json))

    end_time = time.time()
    total_time += end_time - start_time
    logging.info("Time taken: {:.2f} seconds".format(end_time - start_time))
    print("Processing abstract {}, time taken: {:.2f} seconds".format(i, end_time - start_time))
    # end for loop

    # save results each 10 abstracts
    if i % 5 == 0:
      with open(result_json_file, 'w') as file:
        json.dump(result_json_list, file, indent=4)

  # save the final result
  with open(result_json_file, 'w') as file:
    json.dump(result_json_list, file, indent=4)

  try:
    with open(result_invalid_file, 'w') as file:
      file.write(result_invalid_str)
  except:
    with open(result_invalid_file, 'w', encoding='utf-8') as file:
      file.write(result_invalid_str)

  with open(result_invalid_doi_file, 'w') as file:
    for invalid_doi in result_invalid_doi_list:   # if empty, doi = nan, then need to convert to string
      file.write(str(invalid_doi) + '\n')

  logging.info("-------------"*5)
  logging.info("Successfully extracted: {} / {}".format(len(result_json_list), len(abstract_list)))
  logging.info("Total time: {}, averaged time: {} seconds".format(total_time, total_time/len(result_json_list)))

# %%
class Args:
  def __init__(self):
    self.num = 50
    self.start_index = None
    self.save_dir = "/content/drive/MyDrive/Colab Notebooks/W2R/extraction_finetune_unsloth/result_basic_HF_model"
    self.save_dir_rewrite = True
    self.repeat = 5

# Create an instance of Args
args = Args()
base_folder = args.save_dir

# Run the process_abstracts function
for i in range(args.repeat):
  print("Running experiment {}/{}".format(i+1, args.repeat))
  logging.info("Running experiment {}/{}".format(i+1, args.repeat))


  # create subfolder in the save_dir: run_{i}
  save_dir = os.path.join(base_folder, "run_{}".format(i))
  args.save_dir = check_make_dir(save_dir, exist_ok=args.save_dir_rewrite)

  # set logging file
  logger = logging.getLogger()
  if logger.hasHandlers():
    logger.handlers.clear()
  log_file = os.path.join(args.save_dir, "extraction_log.log")
  logging.basicConfig(filename=log_file, filemode='w', level=logging.INFO, format='%(message)s')

  # Log each argument and its value
  for arg, value in vars(args).items():
    logging.info(f'Argument {arg}: {value}')
    print(f'{arg}: {value}')
  logging.info("-------------"*5)

  process_abstracts(args)
# Out:
# Running experiment 1/5
# num: 50
# start_index: None
# save_dir: /content/drive/MyDrive/Colab Notebooks/W2R/extraction_finetune_unsloth/result_basic_HF_model/run_0
# save_dir_rewrite: True
# repeat: 5
# Processing abstract 0, time taken: 2.77 seconds
# Processing abstract 1, time taken: 5.28 seconds
# Processing abstract 2, time taken: 7.10 seconds
# Processing abstract 3, time taken: 3.44 seconds
# Processing abstract 4, time taken: 3.50 seconds
# Processing abstract 5, time taken: 6.56 seconds
# Processing abstract 6, time taken: 3.70 seconds
# Processing abstract 7, time taken: 3.07 seconds
# Processing abstract 8, time taken: 2.39 seconds
# Processing abstract 9, time taken: 5.69 seconds
# Processing abstract 10, time taken: 1.75 seconds
# Processing abstract 11, time taken: 4.22 seconds
# Processing abstract 12, time taken: 2.14 seconds
# Processing abstract 13, time taken: 1.77 seconds
# Processing abstract 14, time taken: 2.69 seconds
# Processing abstract 15, time taken: 6.47 seconds
# Processing abstract 16, time taken: 2.35 seconds
# Processing abstract 17, time taken: 2.09 seconds
# Processing abstract 18, time taken: 3.90 seconds
# Processing abstract 19, time taken: 2.71 seconds
# Processing abstract 20, time taken: 3.46 seconds
# Processing abstract 21, time taken: 5.41 seconds
# Processing abstract 22, time taken: 3.56 seconds
# Processing abstract 23, time taken: 3.09 seconds
# Processing abstract 24, time taken: 2.60 seconds
# Processing abstract 25, time taken: 2.17 seconds
# Processing abstract 26, time taken: 6.22 seconds
# Processing abstract 27, time taken: 1.99 seconds
# Processing abstract 28, time taken: 1.87 seconds
# Processing abstract 29, time taken: 4.71 seconds
# Processing abstract 30, time taken: 7.65 seconds
# Processing abstract 31, time taken: 3.30 seconds
# Processing abstract 32, time taken: 2.45 seconds
# Processing abstract 33, time taken: 6.06 seconds
# Processing abstract 34, time taken: 2.27 seconds
# Processing abstract 35, time taken: 2.60 seconds
# Processing abstract 36, time taken: 2.28 seconds
# Processing abstract 37, time taken: 2.52 seconds
# Processing abstract 38, time taken: 4.61 seconds
# Processing abstract 39, time taken: 3.29 seconds
# Processing abstract 40, time taken: 4.20 seconds
# Processing abstract 41, time taken: 3.03 seconds
# Processing abstract 42, time taken: 2.28 seconds
# Processing abstract 43, time taken: 4.75 seconds
# Processing abstract 44, time taken: 3.52 seconds
# Processing abstract 45, time taken: 4.85 seconds
# Processing abstract 46, time taken: 3.89 seconds
# Processing abstract 47, time taken: 2.35 seconds
# Processing abstract 48, time taken: 4.27 seconds
# Processing abstract 49, time taken: 4.57 seconds
# Running experiment 2/5
# num: 50
# start_index: None
# save_dir: /content/drive/MyDrive/Colab Notebooks/W2R/extraction_finetune_unsloth/result_basic_HF_model/run_1
# save_dir_rewrite: True
# repeat: 5
# Processing abstract 0, time taken: 3.17 seconds
# Processing abstract 1, time taken: 5.53 seconds
# Processing abstract 2, time taken: 7.42 seconds
# Processing abstract 3, time taken: 4.62 seconds
# Processing abstract 4, time taken: 6.13 seconds
# Processing abstract 5, time taken: 7.32 seconds
# Processing abstract 6, time taken: 5.05 seconds
# Processing abstract 7, time taken: 6.95 seconds
# Processing abstract 8, time taken: 2.21 seconds
# Processing abstract 9, time taken: 3.84 seconds
# Processing abstract 10, time taken: 2.66 seconds
# Processing abstract 11, time taken: 4.10 seconds
# Processing abstract 12, time taken: 2.77 seconds
# Processing abstract 13, time taken: 3.32 seconds
# Processing abstract 14, time taken: 3.50 seconds
# Processing abstract 15, time taken: 6.97 seconds
# Processing abstract 16, time taken: 2.45 seconds
# Processing abstract 17, time taken: 3.13 seconds
# Processing abstract 18, time taken: 3.35 seconds
# Processing abstract 19, time taken: 2.55 seconds
# Processing abstract 20, time taken: 2.52 seconds
# Processing abstract 21, time taken: 3.93 seconds
# Processing abstract 22, time taken: 3.74 seconds
# Processing abstract 23, time taken: 3.11 seconds
# Processing abstract 24, time taken: 2.57 seconds
# Processing abstract 25, time taken: 2.91 seconds
# Processing abstract 26, time taken: 5.84 seconds
# Processing abstract 27, time taken: 2.04 seconds
# Processing abstract 28, time taken: 1.92 seconds
# Processing abstract 29, time taken: 6.89 seconds
# Processing abstract 30, time taken: 8.27 seconds
# Processing abstract 31, time taken: 5.27 seconds
# Processing abstract 32, time taken: 3.52 seconds
# Processing abstract 33, time taken: 4.84 seconds
# Processing abstract 34, time taken: 4.38 seconds
# Processing abstract 35, time taken: 4.70 seconds
# Processing abstract 36, time taken: 4.95 seconds
# Processing abstract 37, time taken: 3.08 seconds
# Processing abstract 38, time taken: 4.13 seconds
# Processing abstract 39, time taken: 6.29 seconds
# Processing abstract 40, time taken: 5.17 seconds
# Processing abstract 41, time taken: 2.39 seconds
# Processing abstract 42, time taken: 2.12 seconds
# Processing abstract 43, time taken: 3.76 seconds
# Processing abstract 44, time taken: 4.01 seconds
# Processing abstract 45, time taken: 4.39 seconds
# Processing abstract 46, time taken: 7.74 seconds
# Processing abstract 47, time taken: 3.77 seconds
# Processing abstract 48, time taken: 5.64 seconds
# Processing abstract 49, time taken: 5.99 seconds
# Running experiment 3/5
# num: 50
# start_index: None
# save_dir: /content/drive/MyDrive/Colab Notebooks/W2R/extraction_finetune_unsloth/result_basic_HF_model/run_2
# save_dir_rewrite: True
# repeat: 5
# Processing abstract 0, time taken: 4.71 seconds
# Processing abstract 1, time taken: 10.69 seconds
# Processing abstract 2, time taken: 8.04 seconds
# Processing abstract 3, time taken: 6.11 seconds
# Processing abstract 4, time taken: 2.81 seconds
# Processing abstract 5, time taken: 3.70 seconds
# Processing abstract 6, time taken: 4.43 seconds
# Processing abstract 7, time taken: 4.18 seconds
# Processing abstract 8, time taken: 3.83 seconds
# Processing abstract 9, time taken: 4.41 seconds
# Processing abstract 10, time taken: 2.23 seconds
# Processing abstract 11, time taken: 7.12 seconds
# Processing abstract 12, time taken: 3.90 seconds
# Processing abstract 13, time taken: 4.01 seconds
# Processing abstract 14, time taken: 3.13 seconds
# Processing abstract 15, time taken: 5.67 seconds
# Processing abstract 16, time taken: 2.46 seconds
# Processing abstract 17, time taken: 3.67 seconds
# Processing abstract 18, time taken: 3.39 seconds
# Processing abstract 19, time taken: 2.39 seconds
# Processing abstract 20, time taken: 2.88 seconds
# Processing abstract 21, time taken: 3.56 seconds
# Processing abstract 22, time taken: 4.34 seconds
# Processing abstract 23, time taken: 3.72 seconds
# Processing abstract 24, time taken: 2.88 seconds
# Processing abstract 25, time taken: 2.02 seconds
# Processing abstract 26, time taken: 6.35 seconds
# Processing abstract 27, time taken: 2.05 seconds
# Processing abstract 28, time taken: 1.93 seconds
# Processing abstract 29, time taken: 4.19 seconds
# Processing abstract 30, time taken: 3.72 seconds
# Processing abstract 31, time taken: 3.82 seconds
# Processing abstract 32, time taken: 2.69 seconds
# Processing abstract 33, time taken: 3.20 seconds
# Processing abstract 34, time taken: 3.41 seconds
# Processing abstract 35, time taken: 2.15 seconds
# Processing abstract 36, time taken: 3.02 seconds
# Processing abstract 37, time taken: 2.45 seconds
# Processing abstract 38, time taken: 4.10 seconds
# Processing abstract 39, time taken: 5.37 seconds
# Processing abstract 40, time taken: 5.77 seconds
# Processing abstract 41, time taken: 2.38 seconds
# Processing abstract 42, time taken: 3.10 seconds
# Processing abstract 43, time taken: 5.39 seconds
# Processing abstract 44, time taken: 3.85 seconds
# Processing abstract 45, time taken: 6.42 seconds
# Processing abstract 46, time taken: 5.78 seconds
# Processing abstract 47, time taken: 2.47 seconds
# Processing abstract 48, time taken: 3.62 seconds
# Processing abstract 49, time taken: 3.36 seconds
# Running experiment 4/5
# num: 50
# start_index: None
# save_dir: /content/drive/MyDrive/Colab Notebooks/W2R/extraction_finetune_unsloth/result_basic_HF_model/run_3
# save_dir_rewrite: True
# repeat: 5
# Processing abstract 0, time taken: 3.82 seconds
# Processing abstract 1, time taken: 4.51 seconds
# Processing abstract 2, time taken: 6.66 seconds
# Processing abstract 3, time taken: 4.94 seconds
# Processing abstract 4, time taken: 2.07 seconds
# Processing abstract 5, time taken: 6.44 seconds
# Processing abstract 6, time taken: 2.89 seconds
# Processing abstract 7, time taken: 2.12 seconds
# Processing abstract 8, time taken: 2.27 seconds
# Processing abstract 9, time taken: 6.46 seconds
# Processing abstract 10, time taken: 3.90 seconds
# Processing abstract 11, time taken: 3.90 seconds
# Processing abstract 12, time taken: 2.82 seconds
# Processing abstract 13, time taken: 3.78 seconds
# Processing abstract 14, time taken: 3.94 seconds
# Processing abstract 15, time taken: 5.46 seconds
# Processing abstract 16, time taken: 2.54 seconds
# Processing abstract 17, time taken: 3.11 seconds
# Processing abstract 18, time taken: 2.49 seconds
# Processing abstract 19, time taken: 2.42 seconds
# Processing abstract 20, time taken: 3.69 seconds
# Processing abstract 21, time taken: 4.59 seconds
# Processing abstract 22, time taken: 3.03 seconds
# Processing abstract 23, time taken: 3.55 seconds
# Processing abstract 24, time taken: 2.76 seconds
# Processing abstract 25, time taken: 3.20 seconds
# Processing abstract 26, time taken: 6.16 seconds
# Processing abstract 27, time taken: 2.09 seconds
# Processing abstract 28, time taken: 1.96 seconds
# Processing abstract 29, time taken: 5.97 seconds
# Processing abstract 30, time taken: 3.49 seconds
# Processing abstract 31, time taken: 2.63 seconds
# Processing abstract 32, time taken: 3.34 seconds
# Processing abstract 33, time taken: 5.11 seconds
# Processing abstract 34, time taken: 2.29 seconds
# Processing abstract 35, time taken: 1.84 seconds
# Processing abstract 36, time taken: 3.10 seconds
# Processing abstract 37, time taken: 3.42 seconds
# Processing abstract 38, time taken: 3.13 seconds
# Processing abstract 39, time taken: 3.39 seconds
# Processing abstract 40, time taken: 3.28 seconds
# Processing abstract 41, time taken: 2.58 seconds
# Processing abstract 42, time taken: 2.43 seconds
# Processing abstract 43, time taken: 6.13 seconds
# Processing abstract 44, time taken: 3.45 seconds
# Processing abstract 45, time taken: 4.50 seconds
# Processing abstract 46, time taken: 6.66 seconds
# Processing abstract 47, time taken: 3.26 seconds
# Processing abstract 48, time taken: 4.93 seconds
# Processing abstract 49, time taken: 4.12 seconds
# Running experiment 5/5
# num: 50
# start_index: None
# save_dir: /content/drive/MyDrive/Colab Notebooks/W2R/extraction_finetune_unsloth/result_basic_HF_model/run_4
# save_dir_rewrite: True
# repeat: 5
# Processing abstract 0, time taken: 3.05 seconds
# Processing abstract 1, time taken: 5.38 seconds
# Processing abstract 2, time taken: 5.57 seconds
# Processing abstract 3, time taken: 4.30 seconds
# Processing abstract 4, time taken: 2.20 seconds
# Processing abstract 5, time taken: 3.49 seconds
# Processing abstract 6, time taken: 2.53 seconds
# Processing abstract 7, time taken: 2.13 seconds
# Processing abstract 8, time taken: 2.51 seconds
# Processing abstract 9, time taken: 5.60 seconds
# Processing abstract 10, time taken: 1.98 seconds
# Processing abstract 11, time taken: 4.05 seconds
# Processing abstract 12, time taken: 2.06 seconds
# Processing abstract 13, time taken: 1.88 seconds
# Processing abstract 14, time taken: 3.47 seconds
# Processing abstract 15, time taken: 5.18 seconds
# Processing abstract 16, time taken: 2.49 seconds
# Processing abstract 17, time taken: 2.66 seconds
# Processing abstract 18, time taken: 3.23 seconds
# Processing abstract 19, time taken: 3.25 seconds
# Processing abstract 20, time taken: 3.66 seconds
# Processing abstract 21, time taken: 8.29 seconds
# Processing abstract 22, time taken: 2.89 seconds
# Processing abstract 23, time taken: 3.17 seconds
# Processing abstract 24, time taken: 2.54 seconds
# Processing abstract 25, time taken: 2.04 seconds
# Processing abstract 26, time taken: 6.35 seconds
# Processing abstract 27, time taken: 2.05 seconds
# Processing abstract 28, time taken: 1.94 seconds
# Processing abstract 29, time taken: 4.29 seconds
# Processing abstract 30, time taken: 6.29 seconds
# Processing abstract 31, time taken: 2.64 seconds
# Processing abstract 32, time taken: 3.05 seconds
# Processing abstract 33, time taken: 3.69 seconds
# Processing abstract 34, time taken: 2.92 seconds
# Processing abstract 35, time taken: 2.43 seconds
# Processing abstract 36, time taken: 2.75 seconds
# Processing abstract 37, time taken: 2.46 seconds
# Processing abstract 38, time taken: 4.12 seconds
# Processing abstract 39, time taken: 3.58 seconds
# Processing abstract 40, time taken: 3.05 seconds
# Processing abstract 41, time taken: 2.58 seconds
# Processing abstract 42, time taken: 2.20 seconds
# Processing abstract 43, time taken: 4.32 seconds
# Processing abstract 44, time taken: 2.99 seconds
# Processing abstract 45, time taken: 4.89 seconds
# Processing abstract 46, time taken: 4.20 seconds
# Processing abstract 47, time taken: 3.48 seconds
# Processing abstract 48, time taken: 3.15 seconds
# Processing abstract 49, time taken: 3.65 seconds

# %% [markdown]
# ## Finetune model

# %%
model = FastLanguageModel.get_peft_model(
    model = orig_model,
    r = 8,   # higher r allow model to learn more parameters
    target_modules = ["q_proj", "k_proj", "v_proj",   # query, key, value projections in the attention layers
                      "o_proj",      # output projection of the attention
                      "gate_proj", "up_proj", "down_proj"],  # related to gating mechanisms within the model
    lora_alpha = 32,   # control how much the learned low-rank matrics affect the original weights, alpha/rank
    lora_dropout = 0.1,
    bias = "none",    # none / all / lora_only
    use_gradient_checkpointing = "unsloth",  # unsloth / True. unsloth reduce VRAM by 30%
    random_state = 40,
    use_rslora = False,    # rank stablised LoRA
    loftq_config = None,   # LoftQ: low-rank and fine-tuned quantizatioin
)
# Out:
# Unsloth: Dropout = 0 is supported for fast patching. You are using dropout = 0.1.
# Unsloth will patch all other layers, except LoRA matrices, causing a performance hit.
# Unsloth 2024.11.5 patched 32 layers with 0 QKV layers, 0 O layers and 0 MLP layers.

# %% [markdown]
# ### Data preparation

# %%
from datasets import Dataset
import json
import os

# %%
def make_instruction_from_abstract():
  instruction_template = """Please read the following text and extract the waste-to-resource information into a json structure with keys of waste and transformed_resource.
The values should be list of strings. You should only use names or phrases to describe wastes and resources.
Keep the value empty if there is no corresponding information. Do not include any explanation. Do not include nested json content.
Follow the format:
{
   "waste": [],
   "transformed_resource": []
}
"""
  return instruction_template

def formatted_prompt(abstract, result)-> str:
  instruction = make_instruction_from_abstract()
  input_x = abstract
  response = json.dumps(result, indent=4)

  llama31_prompt="""<|begin_of_text|><|start_header_id|>system<|end_header_id|>

{}<|eot_id|><|start_header_id|>user<|end_header_id|>

{}<|eot_id|><|start_header_id|>assistant<|end_header_id|>

{}<|eot_id|>"""

  return llama31_prompt.format(instruction, input_x, response)

# %%
EOS_TOKEN = tokenizer.eos_token  # must add this, otherwise the generation will not stop

def prepare_dataset(annotation_file):
  with open(annotation_file, "r", encoding="utf-8") as f:
    data = json.load(f)

  # format
  formatted_data = []
  for entry in data:
    abstract = entry["abstract"]
    result = {"waste": entry["waste"], "transformed_resource": entry["transformed_resource"]}

    text = formatted_prompt(abstract, result) + EOS_TOKEN  # MAYBE DON'T NEED EOS_TOKEN
    formatted_data.append({"text":text})

  dataset = Dataset.from_list(formatted_data)
  return dataset

# %%
annotation_file = "/content/drive/MyDrive/Colab Notebooks/W2R/extraction_finetune_dataset.json"
with open(annotation_file, "r", encoding="utf-8") as f:
  data = json.load(f)

train_data = prepare_dataset(annotation_file)

# %%
print(train_data[-1])
# Out:
# {'text': '<|begin_of_text|><|start_header_id|>system<|end_header_id|>\n\nPlease read the following text and extract the waste-to-resource information into a json structure with keys of waste and transformed_resource.\nThe values should be list of strings. You should only use names or phrases to describe wastes and resources.\nKeep the value empty if there is no corresponding information. Do not include any explanation. Do not include nested json content.\nFollow the format:\n{\n   "waste": [],\n   "transformed_resource": []\n}\n<|eot_id|><|start_header_id|>user<|end_header_id|>\n\nBackground: The increase in fish processing has led to the production of a substantial amount of waste. Sustainable resource management increasingly recognizes the need to use fish and fishery wastes to manufacture edible food items. The utilization of innovative technology for the transformation of fishery waste materials into food-useable ingredients is being studied. Scope and approach: The purpose of this review is to highlight the current advances in the incorporation of fish and fisheries waste in food formulations. This paper looks at the different safety and quality issues associated with the integration of these waste materials into food products and their impact on food quality and consumer acceptance. The regulations pertaining to the incorporation of fishing waste-derived substances into food formulations are also discussed. Key findings and conclusions: Despite the growing incorporation of fish and fisheries waste components into various food products, there is limited research and regulatory guidelines addressing the safety considerations associated with this practice. The current emphasis on waste utilization has prompted numerous studies that prioritize the examination of safety elements associated with the presence of pollutants, germs, and hazardous chemicals coming from these materials that have the potential to pose harm to human health. Legislations must be formulated taking into account the appropriateness of particular waste-derived materials for use in food, together with an evaluation of their potential effects on human health. © 2024 Elsevier Ltd<|eot_id|><|start_header_id|>assistant<|end_header_id|>\n\n{\n    "waste": [\n        "fish and fisheries waste"\n    ],\n    "transformed_resource": [\n        "edible food",\n        "food-useable ingredients"\n    ]\n}<|eot_id|><|eot_id|>'}

# %%
print(len(train_data))
# Out:
# 100

# %% [markdown]
# ### Train the model and save to GDrive

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported   # check if hardware supports bfloat16 precision
import time

trainer = SFTTrainer(
    model = model,
    tokenizer = tokenizer,
    train_dataset = train_data,
    dataset_text_field = "text",     # formatted_data.append({"text":text})
    max_seq_length = max_seq_length,
    dataset_num_proc = 2,  # num of processes for dataset preprocessing, which speeds up data preparation
    packing = False,  # if True, combine shorter sequences to fill each batch, can increase training speed
    args = TrainingArguments(
        per_device_train_batch_size = 2,
        gradient_accumulation_steps = 4,
        warmup_steps = 5,
        num_train_epochs = 5, # set this for 1 full training run,
        # max_steps = 60,     # otherwise, set maximum number of training steps
        learning_rate = 2e-4,
        fp16 = not is_bfloat16_supported(),
        bf16 = is_bfloat16_supported(),
        logging_steps = 1,
        optim = "adamw_8bit",
        weight_decay = 0.01,
        lr_scheduler_type = "linear",
        seed = 40,
        output_dir = "output",
        report_to = "none",  # can export to services like Weights & Biases or TensorBoard
    )
)
# Out:
# Map (num_proc=2):   0%|          | 0/100 [00:00<?, ? examples/s]

# %%
# Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = Tesla T4. Max memory = 14.748 GB.
# 5.984 GB of memory reserved.

# %%
model_name = "finetuned_model_13"
base_dir = "/content/drive/MyDrive/Colab Notebooks/W2R/extraction_finetune_unsloth"   # save to Gdrive

start_time = time.time()

trainer_stats = trainer.train()

end_time = time.time()
print(f"Training time: {(end_time - start_time)/60} minutes")


model.save_pretrained(os.path.join(base_dir, model_name))
tokenizer.save_pretrained(os.path.join(base_dir, model_name))
print("Finetuned model saved at: ", os.path.join(base_dir, model_name))
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 100 | Num Epochs = 5
# O^O/ \_/ \    Batch size per device = 2 | Gradient Accumulation steps = 4
# \        /    Total batch size = 8 | Total steps = 60
#  "-____-"     Number of trainable parameters = 20,971,520
#     <div>
#
#       <progress value='60' max='60' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [60/60 12:54, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.752700</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.647200</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.489700</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.475100</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.192400</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.125700</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>1.986200</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.766600</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.722600</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.610500</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.487400</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.542400</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2.138100</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.545100</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.429800</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>1.403800</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.537300</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.494100</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.527500</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.308900</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.351500</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.392000</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.276300</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.639500</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.833100</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.288600</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.317100</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.343900</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.276900</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.245500</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.255500</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.401900</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.287200</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.412100</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.245700</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.324300</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.277600</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>2.076500</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.257200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.153300</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.039400</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.154500</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.411100</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.228000</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.013500</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.214900</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.125400</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.166700</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1.090800</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.657800</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>1.033300</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>1.147400</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>1.039200</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>1.051900</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.981000</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.995100</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1.041100</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.980600</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.920700</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.035700</td>
#     </tr>
#   </tbody>
# </table><p>
# Training time: 13.424878406524659 minutes
# Finetuned model saved at:  /content/drive/MyDrive/Colab Notebooks/W2R/extraction_finetune_unsloth/finetuned_model_13

# %%
# Show final memory and time stats
used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
used_percentage = round(used_memory         /max_memory*100, 3)
lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
print(f"Peak reserved memory = {used_memory} GB.")
print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
print(f"Peak reserved memory % of max memory = {used_percentage} %.")
print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")
# Out:
# 2611.8182 seconds used for training.
# 43.53 minutes used for training.
# Peak reserved memory = 7.973 GB.
# Peak reserved memory for training = 1.989 GB.
# Peak reserved memory % of max memory = 54.062 %.
# Peak reserved memory for training % of max memory = 13.487 %.

# %% [markdown]
# ## Inference

# %% [markdown]
# **load fine-tuned model**

# %%
max_seq_length = 2048
dtype = None
load_in_4bit = True

# %%
from unsloth import FastLanguageModel
import os

model_name = "finetuned_model_13"
base_dir = "/content/drive/MyDrive/Colab Notebooks/W2R/extraction_finetune_unsloth"   # save to Gdrive

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = os.path.join(base_dir, model_name), # MODEL NAME here
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
)
# Out:
# ==((====))==  Unsloth 2024.11.5: Fast Llama patching. Transformers = 4.46.2.
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.5.1+cu124. CUDA = 7.5. CUDA Toolkit = 12.4.
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.28.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): LlamaForCausalLM(
#       (model): LlamaModel(
#         (embed_tokens): Embedding(128256, 4096, padding_idx=128004)
#         (layers): ModuleList(
#           (0-31): 32 x LlamaDecoderLayer(
#             (self_attn): LlamaAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (rotary_emb): LlamaExtendedRotaryEmbedding()
#             )
#             (mlp): LlamaMLP(
#               (gate_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=14336, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (up_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=14336, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (down_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=14336, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=14336, out_features=8, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=8, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#                 (lora_magnitude_vector): ModuleDict()
#               )
#               (act_fn): SiLU()
#             )
#             (input_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#             (post_attention_layernorm): LlamaRMSNorm((4096,), eps=1e-05)
#           )
#         )
#         (norm): LlamaRMSNorm((4096,), eps=1e-05)
#         (rotary_emb): LlamaRotaryEmbedding()
#       )
#       (lm_head): Linear(in_features=4096, out_features=128256, bias=False)
#     )
#   )
# )

# %%
def make_formatted_prompt(abstract):
  propmt_template = """<|begin_of_text|><|start_header_id|>system<|end_header_id|>

  {instruction}<|eot_id|><|start_header_id|>user<|end_header_id|>

  {input_x}<|eot_id|><|start_header_id|>assistant"""

  instruction = """Please read the following text and extract the waste-to-resource information into a json structure with keys of waste and transformed_resource.
The values should be list of strings. You should only use names or phrases to describe wastes and resources.
Keep the value empty if there is no corresponding information. Do not include any explanation. Do not include nested json content.
Follow the format:
{{
   "waste": [],
   "transformed_resource": []
}}
"""
  input_x = abstract

  formatted_prompt = propmt_template.format(instruction=instruction, input_x=input_x)
  return formatted_prompt

# %% [markdown]
# **Test one example**

# %%
from transformers import TextIteratorStreamer

abstract = "The valorization of tannins from forest by-products is a major opportunity for the sustainable development of the forestry industry. Herein we report the laccase-mediated polymerization of tannins obtained from an aqueous pine bark extract. The reaction was conducted under an oxygen atmosphere at 50°C for 60 min and followed by UV–Vis, fluorescence intensity, phenol content, and viscosity measurements. An insoluble polymer was obtained after 45 min, which was attributed to coupling reactions triggered by phenoxyl radicals within the tannins mixture. The polymer showed a marked increase in thermal stability compared with the precursor pine bark extract, with a total mass loss of less than 12% at temperatures up to 500°C, suggesting potential practical applications in flame retardant materials. Additionally, the polymer showed an 85% DPPH activity and a 60% attenuation of singlet oxygen release upon light irradiation, which supports antioxidant and photoprotective properties for the prepared material. To the best of our knowledge, this is the first report to describe the formation of an insoluble polymer by direct enzymatic reaction of an aqueous tannin extract. In this case, soluble tannins are the sole reactants used to produce a promising versatile material for forest waste valorization. © 2024 Wiley Periodicals LLC."
inputs_string = make_formatted_prompt(abstract)

inputs = tokenizer([inputs_string], return_tensors="pt").to("cuda")

# Initialize the TextIteratorStreamer
text_iter_streamer = TextIteratorStreamer(tokenizer)

# Generate the content using the model and the streamer
_ = model.generate(**inputs, streamer=text_iter_streamer, max_new_tokens=256)

# Collect the generated tokens from the streamer and join them into a single string
generated_text = "".join([token for token in text_iter_streamer])

# Remove the original input part from the generated text, if needed
original_input_text = tokenizer.decode(inputs['input_ids'][0], skip_special_tokens=True)
generated_text = generated_text[len(original_input_text):].strip()

# Print or use the generated content
print("Result: ")
print(generated_text)
# Out:
# Result:
# used to produce a promising versatile material for forest waste valorization. © 2024 Wiley Periodicals LLC.<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
# {
#     "waste": [
#         "pine bark"
#     ],
#     "transformed_resource": [
#         "polymer"
#     ]
# }<|eot_id|>

# %% [markdown]
# **Inference on 50 abstracts**

# %%
import pandas as pd
import logging
import json
import ast
import re

# %% [markdown]
# define some functions

# %%
def extract(abstract, args):
  inputs_string = make_formatted_prompt(abstract)
  inputs = tokenizer([inputs_string], return_tensors="pt").to("cuda")

  # Initialize the TextIteratorStreamer
  text_iter_streamer = TextIteratorStreamer(tokenizer)

  # generate
  _ = model.generate(**inputs, streamer=text_iter_streamer, max_new_tokens=512)
  generated_text = "".join([token for token in text_iter_streamer])

  # Remove the original input part from the generated text, if needed
  original_input_text = tokenizer.decode(inputs['input_ids'][0], skip_special_tokens=True)
  generated_text = generated_text[len(original_input_text):].strip()

  return generated_text

def extract_postprocessing(result):
  # Extract the JSON string from the text (a single JSON object)
  json_match = re.search(r'\{.*?\}', result, re.DOTALL)
  if json_match:
    json_content = json_match.group()
    try:
      # Convert the JSON string to a JSON object
      # json_data = json.loads(json_content)    # DO NOT USE THIS: valid json format use double quotes
      json_data = ast.literal_eval(json_content)    # USE THIS: convert string to dict, single or double quotes are both ok
      # Ensure the JSON object includes the required keys
      required_keys = ["waste", "transformed_resource"]
      for key in required_keys:
          if key not in json_data:
              json_data[key] = []
      json_data["transforming_process"] = []   # add the transforming_process (placeholder)
      logging.info("Conversion succeeds")
      return json_data
    except:
      # If conversion fails, create a JSON with specified keys and empty lists
      logging.info("Conversion fails")
      json_data = {
          "waste": [],
          "transforming_process": [],
          "transformed_resource": []
      }
      return json_data
  else:
    # If no JSON string is found, return a JSON with specified keys and empty lists
    logging.info("No JSON string found")
    json_data = {
        "waste": [],
        "transforming_process": [],
        "transformed_resource": []
    }
  return json_data

def check_make_dir(directory, exist_ok=False):
  if not os.path.exists(directory):
    os.makedirs(directory)
    return directory
  else:
    if not exist_ok:
      i = 1
      # increment until finding an available name
      new_dir = f"{directory}_{i}"
      while os.path.exists(new_dir):
        i += 1
        new_dir = f"{directory}_{i}"
      os.makedirs(new_dir)
      return new_dir
    return directory

# %%
def process_abstracts(args):

  # num, model, prompt, save_dir, shot_length, shot_k

  result_json_file = os.path.join(args.save_dir, "w2r_results.json")
  result_invalid_file = os.path.join(args.save_dir, "w2r_invalid.txt")
  result_invalid_doi_file = os.path.join(args.save_dir, "w2r_invalid_doi.txt")

  df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/W2R/scopus_waste2resource.csv")
  abstract_list = df["Abstract"].tolist()
  doi_list = df["DOI"].tolist()

  if args.start_index:
    abstract_list = abstract_list[args.start_index:]
    doi_list = doi_list[args.start_index:]

  if args.num > 0:
    abstract_list = abstract_list[:args.num]
    doi_list = doi_list[:args.num]

  result_json_list = []
  result_invalid_str = ""
  result_invalid_doi_list = []

  total_time = 0

  for i, abstract in enumerate(abstract_list):
    start_time = time.time()

    # get llm output and process
    coded_abstract = abstract   # no need to wrap
    result_str = extract(coded_abstract, args)
    result_json = extract_postprocessing(result_str)

    # add the referece and append
    result_json["reference"] = doi_list[i]
    result_json_list.append(result_json)

    # check if the extracted information is valid
    if len(result_json["waste"]) == 0 and len(result_json["transforming_process"]) == 0 and len(result_json["transformed_resource"]) == 0:
      result_invalid_str += result_str + "\n\n----------\n\n"
      result_invalid_doi_list.append(doi_list[i])

    logging.info("----------------------------------")
    logging.info("Processing abstract {}".format(i))
    logging.info("Coded abstract: \n{}".format(coded_abstract))
    logging.info("LLM response: \n{}".format(result_str))
    logging.info("Extracted w2r: \n{}".format(result_json))

    end_time = time.time()
    total_time += end_time - start_time
    logging.info("Time taken: {:.2f} seconds".format(end_time - start_time))
    print("Processing abstract {}, time taken: {:.2f} seconds".format(i, end_time - start_time))
    # end for loop

    # save results each 10 abstracts
    if i % 10 == 0:
      with open(result_json_file, 'w') as file:
        json.dump(result_json_list, file, indent=4)

  # save the final result
  with open(result_json_file, 'w') as file:
    json.dump(result_json_list, file, indent=4)

  try:
    with open(result_invalid_file, 'w') as file:
      file.write(result_invalid_str)
  except:
    with open(result_invalid_file, 'w', encoding='utf-8') as file:
      file.write(result_invalid_str)

  with open(result_invalid_doi_file, 'w') as file:
    for invalid_doi in result_invalid_doi_list:   # if empty, doi = nan, then need to convert to string
      file.write(str(invalid_doi) + '\n')

  logging.info("-------------"*5)
  logging.info("Successfully extracted: {} / {}".format(len(result_json_list), len(abstract_list)))
  logging.info("Total time: {}, averaged time: {} seconds".format(total_time, total_time/len(result_json_list)))

# %% [markdown]
# run inference

# %%
class Args:
  def __init__(self):
    self.num = 50
    self.start_index = None
    self.save_dir = "/content/drive/MyDrive/Colab Notebooks/W2R/extraction_finetune_unsloth/result_13"
    self.save_dir_rewrite = True
    self.repeat = 5

# Create an instance of Args
args = Args()
base_folder = args.save_dir

# Run the process_abstracts function
for i in range(args.repeat):
  print("Running experiment {}/{}".format(i+1, args.repeat))
  logging.info("Running experiment {}/{}".format(i+1, args.repeat))


  # create subfolder in the save_dir: run_{i}
  save_dir = os.path.join(base_folder, "run_{}".format(i))
  args.save_dir = check_make_dir(save_dir, exist_ok=args.save_dir_rewrite)

  # set logging file
  logger = logging.getLogger()
  if logger.hasHandlers():
    logger.handlers.clear()
  log_file = os.path.join(args.save_dir, "extraction_log.log")
  logging.basicConfig(filename=log_file, filemode='w', level=logging.INFO, format='%(message)s')

  # Log each argument and its value
  for arg, value in vars(args).items():
    logging.info(f'Argument {arg}: {value}')
    print(f'{arg}: {value}')
  logging.info("-------------"*5)

  process_abstracts(args)
# Out:
# Running experiment 1/5
# num: 50
# start_index: None
# save_dir: /content/drive/MyDrive/Colab Notebooks/W2R/extraction_finetune_unsloth/result_13/run_0
# save_dir_rewrite: True
# repeat: 5
# Processing abstract 0, time taken: 6.01 seconds
# Processing abstract 1, time taken: 7.40 seconds
# Processing abstract 2, time taken: 4.02 seconds
# Processing abstract 3, time taken: 3.46 seconds
# Processing abstract 4, time taken: 2.84 seconds
# Processing abstract 5, time taken: 3.65 seconds
# Processing abstract 6, time taken: 3.18 seconds
# Processing abstract 7, time taken: 3.17 seconds
# Processing abstract 8, time taken: 2.63 seconds
# Processing abstract 9, time taken: 5.29 seconds
# Processing abstract 10, time taken: 3.09 seconds
# Processing abstract 11, time taken: 6.67 seconds
# Processing abstract 12, time taken: 3.58 seconds
# Processing abstract 13, time taken: 3.25 seconds
# Processing abstract 14, time taken: 3.66 seconds
# Processing abstract 15, time taken: 9.53 seconds
# Processing abstract 16, time taken: 3.35 seconds
# Processing abstract 17, time taken: 2.62 seconds
# Processing abstract 18, time taken: 3.18 seconds
# Processing abstract 19, time taken: 4.02 seconds
# Processing abstract 20, time taken: 3.43 seconds
# Processing abstract 21, time taken: 2.94 seconds
# Processing abstract 22, time taken: 2.92 seconds
# Processing abstract 23, time taken: 4.58 seconds
# Processing abstract 24, time taken: 3.19 seconds
# Processing abstract 25, time taken: 2.89 seconds
# Processing abstract 26, time taken: 6.70 seconds
# Processing abstract 27, time taken: 3.75 seconds
# Processing abstract 28, time taken: 2.95 seconds
# Processing abstract 29, time taken: 3.81 seconds
# Processing abstract 30, time taken: 4.07 seconds
# Processing abstract 31, time taken: 2.81 seconds
# Processing abstract 32, time taken: 3.64 seconds
# Processing abstract 33, time taken: 3.13 seconds
# Processing abstract 34, time taken: 3.80 seconds
# Processing abstract 35, time taken: 3.38 seconds
# Processing abstract 36, time taken: 3.08 seconds
# Processing abstract 37, time taken: 3.18 seconds
# Processing abstract 38, time taken: 4.02 seconds
# Processing abstract 39, time taken: 3.00 seconds
# Processing abstract 40, time taken: 3.23 seconds
# Processing abstract 41, time taken: 3.30 seconds
# Processing abstract 42, time taken: 3.18 seconds
# Processing abstract 43, time taken: 4.08 seconds
# Processing abstract 44, time taken: 2.82 seconds
# Processing abstract 45, time taken: 5.72 seconds
# Processing abstract 46, time taken: 5.02 seconds
# Processing abstract 47, time taken: 2.91 seconds
# Processing abstract 48, time taken: 4.00 seconds
# Processing abstract 49, time taken: 3.15 seconds
# Running experiment 2/5
# num: 50
# start_index: None
# save_dir: /content/drive/MyDrive/Colab Notebooks/W2R/extraction_finetune_unsloth/result_13/run_1
# save_dir_rewrite: True
# repeat: 5
# Processing abstract 0, time taken: 4.49 seconds
# Processing abstract 1, time taken: 5.60 seconds
# Processing abstract 2, time taken: 4.57 seconds
# Processing abstract 3, time taken: 3.93 seconds
# Processing abstract 4, time taken: 3.18 seconds
# Processing abstract 5, time taken: 2.92 seconds
# Processing abstract 6, time taken: 3.37 seconds
# Processing abstract 7, time taken: 3.92 seconds
# Processing abstract 8, time taken: 2.67 seconds
# Processing abstract 9, time taken: 4.51 seconds
# Processing abstract 10, time taken: 3.36 seconds
# Processing abstract 11, time taken: 6.65 seconds
# Processing abstract 12, time taken: 3.09 seconds
# Processing abstract 13, time taken: 2.88 seconds
# Processing abstract 14, time taken: 4.32 seconds
# Processing abstract 15, time taken: 9.31 seconds
# Processing abstract 16, time taken: 4.21 seconds
# Processing abstract 17, time taken: 2.90 seconds
# Processing abstract 18, time taken: 3.10 seconds
# Processing abstract 19, time taken: 3.03 seconds
# Processing abstract 20, time taken: 3.78 seconds
# Processing abstract 21, time taken: 3.17 seconds
# Processing abstract 22, time taken: 2.92 seconds
# Processing abstract 23, time taken: 3.46 seconds
# Processing abstract 24, time taken: 3.51 seconds
# Processing abstract 25, time taken: 4.76 seconds
# Processing abstract 26, time taken: 5.43 seconds
# Processing abstract 27, time taken: 2.98 seconds
# Processing abstract 28, time taken: 3.70 seconds
# Processing abstract 29, time taken: 3.73 seconds
# Processing abstract 30, time taken: 3.87 seconds
# Processing abstract 31, time taken: 3.22 seconds
# Processing abstract 32, time taken: 3.79 seconds
# Processing abstract 33, time taken: 3.19 seconds
# Processing abstract 34, time taken: 2.94 seconds
# Processing abstract 35, time taken: 3.41 seconds
# Processing abstract 36, time taken: 3.81 seconds
# Processing abstract 37, time taken: 3.07 seconds
# Processing abstract 38, time taken: 3.10 seconds
# Processing abstract 39, time taken: 2.37 seconds
# Processing abstract 40, time taken: 4.66 seconds
# Processing abstract 41, time taken: 3.36 seconds
# Processing abstract 42, time taken: 2.77 seconds
# Processing abstract 43, time taken: 3.38 seconds
# Processing abstract 44, time taken: 3.72 seconds
# Processing abstract 45, time taken: 5.85 seconds
# Processing abstract 46, time taken: 3.92 seconds
# Processing abstract 47, time taken: 3.59 seconds
# Processing abstract 48, time taken: 4.02 seconds
# Processing abstract 49, time taken: 3.04 seconds
# Running experiment 3/5
# num: 50
# start_index: None
# save_dir: /content/drive/MyDrive/Colab Notebooks/W2R/extraction_finetune_unsloth/result_13/run_2
# save_dir_rewrite: True
# repeat: 5
# Processing abstract 0, time taken: 2.67 seconds
# Processing abstract 1, time taken: 6.42 seconds
# Processing abstract 2, time taken: 4.08 seconds
# Processing abstract 3, time taken: 4.09 seconds
# Processing abstract 4, time taken: 3.51 seconds
# Processing abstract 5, time taken: 3.08 seconds
# Processing abstract 6, time taken: 2.79 seconds
# Processing abstract 7, time taken: 3.19 seconds
# Processing abstract 8, time taken: 3.72 seconds
# Processing abstract 9, time taken: 5.31 seconds
# Processing abstract 10, time taken: 2.81 seconds
# Processing abstract 11, time taken: 7.25 seconds
# Processing abstract 12, time taken: 3.69 seconds
# Processing abstract 13, time taken: 2.79 seconds
# Processing abstract 14, time taken: 3.40 seconds
# Processing abstract 15, time taken: 10.11 seconds
# Processing abstract 16, time taken: 3.37 seconds
# Processing abstract 17, time taken: 3.32 seconds
# Processing abstract 18, time taken: 4.05 seconds
# Processing abstract 19, time taken: 2.99 seconds
# Processing abstract 20, time taken: 3.71 seconds
# Processing abstract 21, time taken: 3.36 seconds
# Processing abstract 22, time taken: 3.87 seconds
# Processing abstract 23, time taken: 4.24 seconds
# Processing abstract 24, time taken: 3.06 seconds
# Processing abstract 25, time taken: 5.19 seconds
# Processing abstract 26, time taken: 5.38 seconds
# Processing abstract 27, time taken: 2.75 seconds
# Processing abstract 28, time taken: 3.36 seconds
# Processing abstract 29, time taken: 4.37 seconds
# Processing abstract 30, time taken: 3.63 seconds
# Processing abstract 31, time taken: 2.17 seconds
# Processing abstract 32, time taken: 4.34 seconds
# Processing abstract 33, time taken: 3.64 seconds
# Processing abstract 34, time taken: 2.95 seconds
# Processing abstract 35, time taken: 3.16 seconds
# Processing abstract 36, time taken: 3.54 seconds
# Processing abstract 37, time taken: 3.58 seconds
# Processing abstract 38, time taken: 3.09 seconds
# Processing abstract 39, time taken: 2.74 seconds
# Processing abstract 40, time taken: 3.51 seconds
# Processing abstract 41, time taken: 4.14 seconds
# Processing abstract 42, time taken: 2.24 seconds
# Processing abstract 43, time taken: 3.61 seconds
# Processing abstract 44, time taken: 2.82 seconds
# Processing abstract 45, time taken: 5.83 seconds
# Processing abstract 46, time taken: 3.93 seconds
# Processing abstract 47, time taken: 2.89 seconds
# Processing abstract 48, time taken: 4.50 seconds
# Processing abstract 49, time taken: 2.91 seconds
# Running experiment 4/5
# num: 50
# start_index: None
# save_dir: /content/drive/MyDrive/Colab Notebooks/W2R/extraction_finetune_unsloth/result_13/run_3
# save_dir_rewrite: True
# repeat: 5
# Processing abstract 0, time taken: 2.67 seconds
# Processing abstract 1, time taken: 4.38 seconds
# Processing abstract 2, time taken: 4.84 seconds
# Processing abstract 3, time taken: 3.79 seconds
# Processing abstract 4, time taken: 3.19 seconds
# Processing abstract 5, time taken: 3.25 seconds
# Processing abstract 6, time taken: 3.52 seconds
# Processing abstract 7, time taken: 3.24 seconds
# Processing abstract 8, time taken: 2.63 seconds
# Processing abstract 9, time taken: 4.90 seconds
# Processing abstract 10, time taken: 3.52 seconds
# Processing abstract 11, time taken: 6.25 seconds
# Processing abstract 12, time taken: 3.42 seconds
# Processing abstract 13, time taken: 3.78 seconds
# Processing abstract 14, time taken: 3.82 seconds
# Processing abstract 15, time taken: 10.53 seconds
# Processing abstract 16, time taken: 3.10 seconds
# Processing abstract 17, time taken: 2.65 seconds
# Processing abstract 18, time taken: 3.10 seconds
# Processing abstract 19, time taken: 3.79 seconds
# Processing abstract 20, time taken: 4.20 seconds
# Processing abstract 21, time taken: 2.95 seconds
# Processing abstract 22, time taken: 2.89 seconds
# Processing abstract 23, time taken: 5.37 seconds
# Processing abstract 24, time taken: 3.02 seconds
# Processing abstract 25, time taken: 3.08 seconds
# Processing abstract 26, time taken: 6.51 seconds
# Processing abstract 27, time taken: 3.35 seconds
# Processing abstract 28, time taken: 2.92 seconds
# Processing abstract 29, time taken: 3.69 seconds
# Processing abstract 30, time taken: 3.94 seconds
# Processing abstract 31, time taken: 3.13 seconds
# Processing abstract 32, time taken: 3.64 seconds
# Processing abstract 33, time taken: 3.08 seconds
# Processing abstract 34, time taken: 3.37 seconds
# Processing abstract 35, time taken: 3.88 seconds
# Processing abstract 36, time taken: 3.07 seconds
# Processing abstract 37, time taken: 2.90 seconds
# Processing abstract 38, time taken: 3.42 seconds
# Processing abstract 39, time taken: 3.59 seconds
# Processing abstract 40, time taken: 2.81 seconds
# Processing abstract 41, time taken: 3.28 seconds
# Processing abstract 42, time taken: 2.29 seconds
# Processing abstract 43, time taken: 4.26 seconds
# Processing abstract 44, time taken: 2.67 seconds
# Processing abstract 45, time taken: 5.03 seconds
# Processing abstract 46, time taken: 4.55 seconds
# Processing abstract 47, time taken: 3.57 seconds
# Processing abstract 48, time taken: 3.98 seconds
# Processing abstract 49, time taken: 2.88 seconds
# Running experiment 5/5
# num: 50
# start_index: None
# save_dir: /content/drive/MyDrive/Colab Notebooks/W2R/extraction_finetune_unsloth/result_13/run_4
# save_dir_rewrite: True
# repeat: 5
# Processing abstract 0, time taken: 2.96 seconds
# Processing abstract 1, time taken: 5.06 seconds
# Processing abstract 2, time taken: 4.10 seconds
# Processing abstract 3, time taken: 4.10 seconds
# Processing abstract 4, time taken: 4.07 seconds
# Processing abstract 5, time taken: 3.41 seconds
# Processing abstract 6, time taken: 2.82 seconds
# Processing abstract 7, time taken: 3.36 seconds
# Processing abstract 8, time taken: 3.47 seconds
# Processing abstract 9, time taken: 4.52 seconds
# Processing abstract 10, time taken: 2.75 seconds
# Processing abstract 11, time taken: 7.25 seconds
# Processing abstract 12, time taken: 3.02 seconds
# Processing abstract 13, time taken: 2.83 seconds
# Processing abstract 14, time taken: 2.90 seconds
# Processing abstract 15, time taken: 8.82 seconds
# Processing abstract 16, time taken: 3.43 seconds
# Processing abstract 17, time taken: 3.09 seconds
# Processing abstract 18, time taken: 3.93 seconds
# Processing abstract 19, time taken: 3.03 seconds
# Processing abstract 20, time taken: 3.33 seconds
# Processing abstract 21, time taken: 3.18 seconds
# Processing abstract 22, time taken: 4.06 seconds
# Processing abstract 23, time taken: 3.82 seconds
# Processing abstract 24, time taken: 3.30 seconds
# Processing abstract 25, time taken: 4.85 seconds
# Processing abstract 26, time taken: 5.18 seconds
# Processing abstract 27, time taken: 2.79 seconds
# Processing abstract 28, time taken: 2.91 seconds
# Processing abstract 29, time taken: 4.68 seconds
# Processing abstract 30, time taken: 3.32 seconds
# Processing abstract 31, time taken: 2.76 seconds
# Processing abstract 32, time taken: 3.34 seconds
# Processing abstract 33, time taken: 4.29 seconds
# Processing abstract 34, time taken: 2.85 seconds
# Processing abstract 35, time taken: 3.18 seconds
# Processing abstract 36, time taken: 3.14 seconds
# Processing abstract 37, time taken: 4.11 seconds
# Processing abstract 38, time taken: 3.07 seconds
# Processing abstract 39, time taken: 1.69 seconds
# Processing abstract 40, time taken: 3.26 seconds
# Processing abstract 41, time taken: 3.82 seconds
# Processing abstract 42, time taken: 2.82 seconds
# Processing abstract 43, time taken: 3.38 seconds
# Processing abstract 44, time taken: 2.83 seconds
# Processing abstract 45, time taken: 6.32 seconds
# Processing abstract 46, time taken: 3.98 seconds
# Processing abstract 47, time taken: 2.90 seconds
# Processing abstract 48, time taken: 3.57 seconds
# Processing abstract 49, time taken: 3.91 seconds

# %% [markdown]
# ## Clear GPU memory

# %%
del orig_model

torch.cuda.empty_cache()

import gc
gc.collect()
# Out:
# 63
